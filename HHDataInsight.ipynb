# %%
import numpy as np, scipy, pandas as pd
from matplotlib import pyplot as plt
from matplotlib import dates as md
import seaborn as sns, sklearn
from datetime import datetime, timedelta, date, time
import pickle

# %%
#!pip install tensorflow
#tf.__version__

# %% [markdown]
# # load and understand the data

# %%
import boto3 
import json

# read file
with open('/opt/ml/metadata/resource-metadata.json', 'r') as file:
    data=file.read()
# parse file
obj = json.loads(data)
notebookName = str(obj['ResourceName']).lower()
data_key = 'dataslices/1684747985-dataslice.csv'
data_location = 's3://{}/{}'.format(notebookName, data_key)

# %%
# load the data and set the timeline from 2022, convert string format to datetime for convenient manipulation, 
# then convert YYMMDD to YYMMDDHHMMSS, takes up to 3 minutes for the conversion
def generate_dft(data_location):
    dft=pd.read_csv(data_location)
    dft=dft[dft['settlement_date'] >= '2022-01-01']
    dft=dft.reset_index()
    dft=dft.drop(['index'], axis=1) 
    dft['settlement_date']=pd.to_datetime(dft['settlement_date']) 
    dft['settlement_date'] = [dft['settlement_date'][i] + timedelta(hours=0.5)*(dft['settlement_period'][i]-1) for i in range(len(dft))]
    return dft

# %%
dft = generate_dft(data_location)

# %%
dft.head()
# Out:
#   post_code_area     settlement_date  settlement_period  num_mpans  \
# 0             AB 2022-01-01 00:00:00                  1        200
# 1             AB 2022-01-01 00:30:00                  2        200
# 2             AB 2022-01-01 01:00:00                  3        200
# 3             AB 2022-01-01 01:30:00                  4        200
# 4             AB 2022-01-01 02:00:00                  5        200
#
#    avg_vol_per_mpan
# 0               0.3
# 1               0.3
# 2               0.3
# 3               0.3
# 4               0.4

# %%
# check datetypes of the columns

print(type(dft.loc[0,'post_code_area']), type(dft.loc[0,'settlement_date']), type(dft.loc[0,'settlement_period']), type(dft.loc[0,'num_mpans']), type(dft.loc[0,'avg_vol_per_mpan']))
# Out:
# <class 'str'> <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'numpy.int64'> <class 'numpy.int64'> <class 'numpy.float64'>

# %%
# the HH dataset has covered 120 different postal code areas in the UK

len(dft['post_code_area'].unique())
# Out:
# 120

# %%
dft.head()
# Out:
#   post_code_area     settlement_date  settlement_period  num_mpans  \
# 0             AB 2022-01-01 00:00:00                  1        200
# 1             AB 2022-01-01 00:30:00                  2        200
# 2             AB 2022-01-01 01:00:00                  3        200
# 3             AB 2022-01-01 01:30:00                  4        200
# 4             AB 2022-01-01 02:00:00                  5        200
#
#    avg_vol_per_mpan
# 0               0.3
# 1               0.3
# 2               0.3
# 3               0.3
# 4               0.4

# %% [markdown]
# # brief data cleaning

# %%
# some results are clearly outliers and should be removed 
dft[dft['avg_vol_per_mpan']>200]
# Out:
#         post_code_area     settlement_date  settlement_period  num_mpans  \
# 1071288             HS 2022-03-17 04:00:00                  9          6
# 1071289             HS 2022-03-17 04:30:00                 10          6
# 1071290             HS 2022-03-17 05:00:00                 11          6
# 1071291             HS 2022-03-17 05:30:00                 12          6
# 1071292             HS 2022-03-17 06:00:00                 13          6
# ...                ...                 ...                ...        ...
# 1074061             HS 2022-05-13 23:30:00                 48          6
# 1074062             HS 2022-05-14 00:00:00                  1          6
# 1074063             HS 2022-05-14 00:30:00                  2          6
# 1074161             HS 2022-05-16 01:30:00                  4          6
# 1074162             HS 2022-05-16 02:00:00                  5          6
#
#          avg_vol_per_mpan
# 1071288             214.5
# 1071289             227.9
# 1071290             227.4
# 1071291             227.0
# 1071292             231.1
# ...                   ...
# 1074061             233.8
# 1074062             233.8
# 1074063             233.8
# 1074161             219.0
# 1074162             215.2
#
# [333 rows x 5 columns]

# %%
# run this function to remove major outliers

def brief_cleansing(dft):
    dft=dft.loc[dft['post_code_area'] != 'HS']
    dft.loc[dft['avg_vol_per_mpan']<0, 'avg_vol_per_mpan']=0
    #dft.loc[(dft['settlement_date'] > pd.Timestamp('2021-07-01')) & (dft['settlement_date'] < pd.Timestamp('2021-10-01')) & (dft['avg_vol_per_mpan']>50), 'avg_vol_per_mpan']=50
    dft.loc[(dft['settlement_date'] > pd.Timestamp('2022-09-01')) & (dft['settlement_date'] < pd.Timestamp('2023-03-01')) & (dft['avg_vol_per_mpan']>5), 'avg_vol_per_mpan']=2
    dft = dft.loc[(dft['settlement_date'] >= pd.Timestamp('2022-03-01')) & (dft['settlement_date'] <= pd.Timestamp('2023-04-01'))]
    return dft

# %%
dft = brief_cleansing(dft)

# %%
with open('refined dataset.pickle', 'wb') as f:s
            pickle.dump(dft, f)

# %%
with open('refined dataset.pickle', 'rb') as f:
    dft=pickle.load(f)

# %%
def dft_to_list(dft):
    pc = dft['post_code_area'].unique()
    #dft_dict=dict(zip(pc, [dft[dft['post_code_area']==pc[c]] for c in range(len(pc))]))
    dft_list=[]
    for c in range(len(pc)):
        dft_list.append(dft[dft['post_code_area']==pc[c]])
    return dft_list, pc

# %%
dft_list, pc = dft_to_list(dft)

# %% [markdown]
# # seasonality and trend

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
def decomposition_HH(dft):
    dft_hh = dft.drop(['settlement_period', 'num_mpans'], axis=1)
    dft_hh = dft_hh.groupby([dft_hh['settlement_date']]).mean()
    dif = (date(2023,4,1)-date(2022,3,1)).days
    deco = seasonal_decompose(dft_hh['avg_vol_per_mpan'], model='additive', period=dif)
    fig, ax = plt.subplots(3, 1, figsize=(12,9), sharex=True)
    plt.subplots_adjust(hspace=0)
    plt.xlabel('settlement_date')
    deco.trend.plot(ax=ax[0])
    deco.seasonal.plot(ax=ax[1])
    deco.resid.plot(ax=ax[2])
    ax[0].set_ylabel('global trend')
    ax[1].set_ylabel('seasonal')
    ax[2].set_ylabel('residual')
    return plt.show()

# %%
"""the larger the flunctuation in the seasonality, the larger the difference between the day to night consumption during that time period of the year"""
decomposition_HH(dft)
# Out:
# /tmp/ipykernel_14491/1134092740.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_hh = dft_hh.groupby([dft_hh['settlement_date']]).mean()

# %% [markdown]
# # plot variations

# %%
def plot_all_pc(dft_list, pc):
    
    plt.figure(figsize=(12, 6))
    for c in range(len(dft_list)):
        plt.plot(dft_list[c]['settlement_date'], dft_list[c]['avg_vol_per_mpan'], label='{}'.format(pc[c]), linewidth='0.2')
    # plt.legend()
    plt.grid()
    # plt.xlim(pd.Timestamp('2022-01-01 00:00:00'), pd.Timestamp('2023-04-01 00:00:00'))
    plt.xlabel('Timeline with HH resolution')
    plt.ylabel('Average consumption per MPAN')
    plt.title('Average volume consumption per MPAN for each post code area | all in one plot')
    
    return plt.show()

def subplot_all_pc(dft_list, pc):
    
    plt.figure(figsize=(12, 120))
    fig, ax = plt.subplots(120, 1, figsize=(12, 120), sharex=True)
    # plt.xlim(pd.Timestamp('2022-01-01 00:00:00'), pd.Timestamp('2023-04-01 00:00:00'))
    plt.subplots_adjust(hspace=0)
    for c in range(len(dft_list)):
        ax[c].set_ylim(0, 20)
        ax[c].plot(dft_list[c]['settlement_date'], dft_list[c]['avg_vol_per_mpan'], label='{}'.format(pc[c]))
        ax[c].legend()
        fig.text(0.5, 0.04, 'Timeline with HH resolution', ha='center')
        fig.text(0.09, 0.5, 'Average consumption per mpan', va='center', rotation='vertical')  
    plt.title('Average volume consumption per MPAN for each post code area | separate plots')
    
    return plt.show()

# %%
def plot_HH_on_the_day(dft, pc):
    
    dft_hh_pc = dft.drop(['settlement_date', 'num_mpans'], axis=1)
    dft_hh_pc = dft_hh_pc.groupby(['post_code_area', 'settlement_period']).mean()
    dft_hh_pc = dft_hh_pc.reset_index()
    dft_hh_pc_list=[]
    for c in dft_hh_pc['post_code_area'].unique():
        dft_hh_pc_list.append(dft_hh_pc[dft_hh_pc['post_code_area']==c])
    
    plt.figure(figsize=(12, 6))
    # plt.xlim(1, 50)
    # xaxis = ["{02d}:{02d}".format((some_dt+timedelta(hours=0.5)*i).hour, (some_dt+timedelta(hours=0.5)*i).minute) for i in np.arange(48)]
    for c in range(len(dft_hh_pc_list)):
        plt.plot(dft_hh_pc_list[c]['settlement_period'], dft_hh_pc_list[c]['avg_vol_per_mpan'], label='{}'.format(pc[c]), linewidth='0.5')
    # plt.legend()
    plt.xlabel('HH time slot in a day')
    plt.ylabel('Average consumption per mpan per HH time slot')
    plt.title('Average consumption per mpan per HH time slot from 00:00 to 23:59 of an average day for each post code area')
    
    return plt.show()

# %%
def plot_t_res(dft):
    
    dft_m = dft.drop(['settlement_period', 'num_mpans'], axis=1)
    dft_m = dft_m.groupby([dft_m['settlement_date'].dt.to_period('M')]).mean()
    dft_d = dft.drop(['settlement_period', 'num_mpans'], axis=1)
    dft_d = dft_d.groupby([dft_d['settlement_date'].dt.to_period('D')]).mean()
    dft_hh = dft.drop(['settlement_period', 'num_mpans'], axis=1)
    dft_hh = dft_hh.groupby([dft_hh['settlement_date']]).mean()
    
    plt.figure(figsize=(12, 6))
    plt.plot(dft_hh, color='lightgrey') 
    plt.plot(dft_d) 
    plt.plot(dft_m)
    # plt.plot(dft_daymax)
    # plt.plot(dft_daymin)
    plt.legend(['Half-Hourly (HH)', 'Daily', 'Monthly'])
    plt.xlim(pd.Timestamp('2022-03-02 00:00:00'), pd.Timestamp('2023-04-01 00:00:00'))
    plt.xlabel('Timeline with different resolutions')
    plt.ylabel('Average consumption per mpan')
    plt.title('Average consumption per mpan averaged across all post codes with different timeline resolutions')
    
    return plt.show()

# %%
def plot_mpans(dft):
    
    dft_list, pc = dft_to_list(dft)
    ind_EH = np.argwhere(pc=='EH').ravel()[0]
    ind_B = np.argwhere(pc=='B').ravel()[0]
    ind_M = np.argwhere(pc=='M').ravel()[0]

    ind_London = [np.argwhere(pc=='E'), np.argwhere(pc=='EC'), np.argwhere(pc=='N'), np.argwhere(pc=='NW'), np.argwhere(pc=='SE'), np.argwhere(pc=='SW'), np.argwhere(pc=='W'), np.argwhere(pc=='WC')]
    dft_London = pd.DataFrame(np.vstack([dft_list[i] for i in np.array(ind_London).ravel()]), columns=dft.columns) 
    dft_London = dft_London.drop(['post_code_area', 'avg_vol_per_mpan', 'settlement_period'], axis=1)
    dft_London = dft_London.groupby(['settlement_date']).sum()  
    dft_London.reset_index(inplace=True)
    
    fig, ((ax11, ax12), (ax21, ax22)) = plt.subplots(2, 2, figsize=(13, 6), sharey=True, sharex=True)
    ax11.plot(dft_list[ind_EH]['settlement_date'], dft_list[ind_EH]['num_mpans'], label='Edinburgh')
    ax12.plot(dft_list[ind_B]['settlement_date'], dft_list[ind_B]['num_mpans'], label='Bermingham')
    ax21.plot(dft_list[ind_M]['settlement_date'], dft_list[ind_M]['num_mpans'], label='Manchester')
    ax22.plot(dft_London['settlement_date'], dft_London['num_mpans'], label='London')
    fig.text(0.5, 0.00, 'Timeline with HH resolution', ha='center')
    fig.text(0.00, 0.5, 'num_mpans', va='center', rotation='vertical')  
    ax11.legend(), ax11.grid()
    ax12.legend(), ax12.grid()
    ax21.legend(), ax21.grid()
    ax22.legend(), ax22.grid()
    fig.text(0.32, 1, 'Number of MPANs used for statistics')
    fig.tight_layout(rect=[0, 0, 0.95, 1])
    
    return plt.show()

# %%
def plot_heatmap(dft):
    
    #dft = dft[(dft['settlement_date'] <= pd.Timestamp('2023-04-01')) & (dft['settlement_date'] >= pd.Timestamp('2022-03-01'))]
    dft_list, pc = dft_to_list(dft)
    
    ind_EH = np.argwhere(pc=='EH').ravel()[0]
    dft_EH = dft_list[ind_EH].drop(['post_code_area', 'num_mpans'], axis=1)
    dft_EH = dft_EH.groupby([dft_EH['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()
    dft_EH = dft_EH.reset_index()
    dft_EH['settlement_date'] = dft_EH['settlement_date'].astype('str')
    
    ind_B = np.argwhere(pc=='B').ravel()[0]
    dft_B = dft_list[ind_B].drop(['post_code_area', 'num_mpans'], axis=1)
    dft_B = dft_B.groupby([dft_B['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()
    dft_B = dft_B.reset_index()
    dft_B['settlement_date'] = dft_B['settlement_date'].astype('str') 
    
    ind_M = np.argwhere(pc=='M').ravel()[0]
    dft_M = dft_list[ind_M].drop(['post_code_area', 'num_mpans'], axis=1)
    dft_M = dft_M.groupby([dft_M['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()
    dft_M = dft_M.reset_index()  
    dft_M['settlement_date'] = dft_M['settlement_date'].astype('str') 
    
    ind_London = [np.argwhere(pc=='E'), np.argwhere(pc=='EC'), np.argwhere(pc=='N'), np.argwhere(pc=='NW'), np.argwhere(pc=='SE'), np.argwhere(pc=='SW'), np.argwhere(pc=='W'), np.argwhere(pc=='WC')]
    dft_London = pd.DataFrame(np.vstack([dft_list[i] for i in np.array(ind_London).ravel()]), columns=dft.columns) 
    dft_London = dft_London.drop(['post_code_area', 'num_mpans'], axis=1)
    dft_London = dft_London.groupby([dft_London['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()
    dft_London = dft_London.drop(['settlement_date'], axis=1)
    dft_London = dft_London.reset_index()
    dft_London['settlement_date'] = dft_London['settlement_date'].astype('str') 
    
    fig, ((ax11, ax12), (ax21, ax22)) = plt.subplots(2, 2, figsize=(12, 8), sharey=True, sharex=True)
    ax11.set_title('Edinburgh (EH)')
    ax12.set_title('Birmingham (B)')
    ax21.set_title('Manchester (M)')
    ax22.set_title('London (E, EC, N, NW, SE, SW, W, WC)')
    #ytickdates= ['2022-01-01', '2022-04-01', '2022-07-01','2022-10-01', '2023-01-01', '2023-04-01']
    #yticklabels = [d if d in ytickdates else '' for d in dft_hh_pc_EH['settlement_date'].astype(str)]
    fig11 = sns.heatmap(dft_EH.pivot(columns='settlement_period',index='settlement_date',values='avg_vol_per_mpan'), ax=ax11)
    fig12 = sns.heatmap(dft_B.pivot(columns='settlement_period',index='settlement_date',values='avg_vol_per_mpan'), ax=ax12)
    fig21 = sns.heatmap(dft_M.pivot(columns='settlement_period',index='settlement_date',values='avg_vol_per_mpan'), ax=ax21)
    fig22 = sns.heatmap(dft_London.pivot(columns='settlement_period', index='settlement_date', values='avg_vol_per_mpan'), ax=ax22)
    #fig.add_axes([0.94, 0.3, 0.03, 0.4])
    fig.text(0.5, 0.0, 'HH time slot in a day', ha='center')
    fig.text(0.0, 0.5, 'Average consumption per mpan', va='center', rotation='vertical')  
    fig.text(0.32, 1, 'Heatmap of average daily consumption per mpan')
    fig.tight_layout(rect=[0, 0, 0.95, 1])
    
    return plt.show()

# %%
#plot_all_pc(dft_list, pc)
#subplot_all_pc(dft_list, pc)

# %%
plot_HH_on_the_day(dft, pc)

# %%
plot_t_res(dft)
# Out:
# /tmp/ipykernel_25901/4095459288.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_m = dft_m.groupby([dft_m['settlement_date'].dt.to_period('M')]).mean()
# /tmp/ipykernel_25901/4095459288.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_d = dft_d.groupby([dft_d['settlement_date'].dt.to_period('D')]).mean()
# /tmp/ipykernel_25901/4095459288.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_hh = dft_hh.groupby([dft_hh['settlement_date']]).mean()

# %%
plot_mpans(dft)

# %%
plot_heatmap(dft)
# Out:
# /tmp/ipykernel_14491/4104833289.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_EH = dft_EH.groupby([dft_EH['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()
# /tmp/ipykernel_14491/4104833289.py:14: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_B = dft_B.groupby([dft_B['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()
# /tmp/ipykernel_14491/4104833289.py:20: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dft_M = dft_M.groupby([dft_M['settlement_date'].dt.to_period('D'), 'settlement_period']).mean()

# %% [markdown]
# # PCA analysis - unsupervised machine learning (optional)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# can take a while with progress track
dates = dft.loc[(dft['settlement_date']>=pd.Timestamp('2022-01-01')), 'settlement_date'].dt.date.unique()
def pca_sample_list(dft_list, pc, dates):
    sample_list=[]
    for m in range(len(dates)):
        print('sample data formation progress: {:.3f}%   '.format(100*m/len(dates)), end='\r')
        instance_list=[]
        for c in range(len(pc)):
            instance = dft_list[c].loc[dft_list[c]['settlement_date'].dt.date==dates[m], 'avg_vol_per_mpan']
            if len(instance) == 48:
                instance_list.append(instance)
            else:
                pass
        if instance_list:
            sample_list.append(np.vstack(instance_list))
        else:
            pass
    print('sample matrix formation progress: 100.000%', end='\r')
    if sample_list:
        pass
    else:
        raise ValueError('need a non-empty list to return, use a larger range of dates to run this function')
    return sample_list

# %%
sample_list = pca_sample_list(dft_list, pc, dates)
# Out:
# sample matrix formation progress: 100.000%

# %%
def reduce_dim(sample_list, nComp):
    pca = PCA(n_components=nComp)
    X_r_list = []
    pca_list = []
    for m in range(len(sample_list)):
        X = StandardScaler().fit_transform(sample_list[m])
        X_r = pca.fit_transform(X)
        print("explained variance ratio of each component for profile {} in the list: ".format(m), pca.explained_variance_ratio_)
        X_r_list.append(X_r)
        pca_list.append(pca)
    return X_r_list, pca_list

# %%
X_r_list, pca_list = reduce_dim(sample_list, 2)
# Out:
# explained variance ratio of each component for profile 0 in the list:  [0.86483774 0.12757291]
# explained variance ratio of each component for profile 1 in the list:  [0.82272469 0.15262144]
# explained variance ratio of each component for profile 2 in the list:  [0.82298136 0.15332799]
# explained variance ratio of each component for profile 3 in the list:  [0.87177347 0.12037568]
# explained variance ratio of each component for profile 4 in the list:  [0.87767332 0.11453636]
# explained variance ratio of each component for profile 5 in the list:  [0.87639977 0.1165164 ]
# explained variance ratio of each component for profile 6 in the list:  [0.84125386 0.13583748]
# explained variance ratio of each component for profile 7 in the list:  [0.83878405 0.14049751]
# explained variance ratio of each component for profile 8 in the list:  [0.83145174 0.14548489]
# explained variance ratio of each component for profile 9 in the list:  [0.82978579 0.14528153]
# explained variance ratio of each component for profile 10 in the list:  [0.81418526 0.15892047]
# explained variance ratio of each component for profile 11 in the list:  [0.84858772 0.14230911]
# explained variance ratio of each component for profile 12 in the list:  [0.81366775 0.1599963 ]
# explained variance ratio of each component for profile 13 in the list:  [0.85505194 0.1360498 ]
# explained variance ratio of each component for profile 14 in the list:  [0.85416449 0.1366625 ]
# explained variance ratio of each component for profile 15 in the list:  [0.85087512 0.13963645]
# explained variance ratio of each component for profile 16 in the list:  [0.84196878 0.1479571 ]
# explained variance ratio of each component for profile 17 in the list:  [0.84527463 0.14524961]
# explained variance ratio of each component for profile 18 in the list:  [0.84599872 0.14465073]
# explained variance ratio of each component for profile 19 in the list:  [0.84562646 0.14535544]
# explained variance ratio of each component for profile 20 in the list:  [0.84432887 0.14613755]
# explained variance ratio of each component for profile 21 in the list:  [0.83464232 0.14657741]
# explained variance ratio of each component for profile 22 in the list:  [0.84307262 0.1482837 ]
# explained variance ratio of each component for profile 23 in the list:  [0.84926888 0.14164658]
# explained variance ratio of each component for profile 24 in the list:  [0.84350947 0.14475754]
# explained variance ratio of each component for profile 25 in the list:  [0.84474595 0.14220546]
# explained variance ratio of each component for profile 26 in the list:  [0.85151826 0.13885255]
# explained variance ratio of each component for profile 27 in the list:  [0.85030875 0.13833193]
# explained variance ratio of each component for profile 28 in the list:  [0.85083016 0.13947674]
# explained variance ratio of each component for profile 29 in the list:  [0.84836924 0.14121295]
# explained variance ratio of each component for profile 30 in the list:  [0.84047201 0.14985417]
# explained variance ratio of each component for profile 31 in the list:  [0.8528383  0.13508915]
# explained variance ratio of each component for profile 32 in the list:  [0.85900362 0.13147044]
# explained variance ratio of each component for profile 33 in the list:  [0.85426171 0.13614501]
# explained variance ratio of each component for profile 34 in the list:  [0.8438011  0.13830685]
# explained variance ratio of each component for profile 35 in the list:  [0.84482402 0.13705908]
# explained variance ratio of each component for profile 36 in the list:  [0.84153583 0.13814983]
# explained variance ratio of each component for profile 37 in the list:  [0.84988471 0.13598315]
# explained variance ratio of each component for profile 38 in the list:  [0.84383323 0.14344012]
# explained variance ratio of each component for profile 39 in the list:  [0.84897232 0.13872332]
# explained variance ratio of each component for profile 40 in the list:  [0.83218505 0.14781946]
# explained variance ratio of each component for profile 41 in the list:  [0.84745913 0.14235274]
# explained variance ratio of each component for profile 42 in the list:  [0.83525725 0.14526781]
# explained variance ratio of each component for profile 43 in the list:  [0.843589   0.14647633]
# explained variance ratio of each component for profile 44 in the list:  [0.84166166 0.14820263]
# explained variance ratio of each component for profile 45 in the list:  [0.84469107 0.1458009 ]
# explained variance ratio of each component for profile 46 in the list:  [0.837965   0.14898542]
# explained variance ratio of each component for profile 47 in the list:  [0.83331291 0.14670331]
# explained variance ratio of each component for profile 48 in the list:  [0.82936376 0.14864992]
# explained variance ratio of each component for profile 49 in the list:  [0.829001   0.14761916]
# explained variance ratio of each component for profile 50 in the list:  [0.82990733 0.14930557]
# explained variance ratio of each component for profile 51 in the list:  [0.82947063 0.14796856]
# explained variance ratio of each component for profile 52 in the list:  [0.82504148 0.14910212]
# explained variance ratio of each component for profile 53 in the list:  [0.82741839 0.1493786 ]
# explained variance ratio of each component for profile 54 in the list:  [0.81743665 0.15950053]
# explained variance ratio of each component for profile 55 in the list:  [0.81967154 0.15712312]
# explained variance ratio of each component for profile 56 in the list:  [0.80621591 0.16688502]
# explained variance ratio of each component for profile 57 in the list:  [0.81623413 0.17143921]
# explained variance ratio of each component for profile 58 in the list:  [0.83538823 0.15256895]
# explained variance ratio of each component for profile 59 in the list:  [0.87678352 0.11489596]
# explained variance ratio of each component for profile 60 in the list:  [0.87145365 0.11337909]
# explained variance ratio of each component for profile 61 in the list:  [0.87844266 0.11233382]
# explained variance ratio of each component for profile 62 in the list:  [0.87277163 0.11153768]
# explained variance ratio of each component for profile 63 in the list:  [0.87134151 0.11093644]
# explained variance ratio of each component for profile 64 in the list:  [0.86404478 0.11692808]
# explained variance ratio of each component for profile 65 in the list:  [0.87946824 0.11455439]
# explained variance ratio of each component for profile 66 in the list:  [0.86216756 0.12604946]
# explained variance ratio of each component for profile 67 in the list:  [0.85996356 0.1216313 ]
# explained variance ratio of each component for profile 68 in the list:  [0.85175531 0.1277322 ]
# explained variance ratio of each component for profile 69 in the list:  [0.86207117 0.12736823]
# explained variance ratio of each component for profile 70 in the list:  [0.85464832 0.13358947]
# explained variance ratio of each component for profile 71 in the list:  [0.8558535  0.13468958]
# explained variance ratio of each component for profile 72 in the list:  [0.85594837 0.13528169]
# explained variance ratio of each component for profile 73 in the list:  [0.85260097 0.13344368]
# explained variance ratio of each component for profile 74 in the list:  [0.84811366 0.1307516 ]
# explained variance ratio of each component for profile 75 in the list:  [0.84747004 0.12286578]
# explained variance ratio of each component for profile 76 in the list:  [0.82781896 0.1523358 ]
# explained variance ratio of each component for profile 77 in the list:  [0.8338373  0.14591826]
# explained variance ratio of each component for profile 78 in the list:  [0.83919346 0.15327813]
# explained variance ratio of each component for profile 79 in the list:  [0.82602396 0.15199427]
# explained variance ratio of each component for profile 80 in the list:  [0.81659148 0.15734198]
# explained variance ratio of each component for profile 81 in the list:  [0.82150053 0.16356066]
# explained variance ratio of each component for profile 82 in the list:  [0.82898455 0.15593064]
# explained variance ratio of each component for profile 83 in the list:  [0.82600886 0.15723934]
# explained variance ratio of each component for profile 84 in the list:  [0.83411497 0.14536816]
# explained variance ratio of each component for profile 85 in the list:  [0.82055278 0.1478049 ]
# explained variance ratio of each component for profile 86 in the list:  [0.84048276 0.1302652 ]
# explained variance ratio of each component for profile 87 in the list:  [0.83338549 0.1395347 ]
# explained variance ratio of each component for profile 88 in the list:  [0.83442044 0.14161094]
# explained variance ratio of each component for profile 89 in the list:  [0.86232516 0.11626704]
# explained variance ratio of each component for profile 90 in the list:  [0.85982931 0.12204571]
# explained variance ratio of each component for profile 91 in the list:  [0.86173514 0.12344052]
# explained variance ratio of each component for profile 92 in the list:  [0.86353325 0.11532117]
# explained variance ratio of each component for profile 93 in the list:  [0.85241015 0.12927468]
# explained variance ratio of each component for profile 94 in the list:  [0.86120429 0.12766225]
# explained variance ratio of each component for profile 95 in the list:  [0.84074773 0.13718074]
# explained variance ratio of each component for profile 96 in the list:  [0.84226997 0.13241724]
# explained variance ratio of each component for profile 97 in the list:  [0.84292296 0.13102029]
# explained variance ratio of each component for profile 98 in the list:  [0.84434502 0.1344557 ]
# explained variance ratio of each component for profile 99 in the list:  [0.82874506 0.13624548]
# explained variance ratio of each component for profile 100 in the list:  [0.82448383 0.12948295]
# explained variance ratio of each component for profile 101 in the list:  [0.84705343 0.13830948]
# explained variance ratio of each component for profile 102 in the list:  [0.85406386 0.12394482]
# explained variance ratio of each component for profile 103 in the list:  [0.85731843 0.12291772]
# explained variance ratio of each component for profile 104 in the list:  [0.85650626 0.13134732]
# explained variance ratio of each component for profile 105 in the list:  [0.8542794  0.13820701]
# explained variance ratio of each component for profile 106 in the list:  [0.84043825 0.13522502]
# explained variance ratio of each component for profile 107 in the list:  [0.84632315 0.12769684]
# explained variance ratio of each component for profile 108 in the list:  [0.83440112 0.13260168]
# explained variance ratio of each component for profile 109 in the list:  [0.81764463 0.13467992]
# explained variance ratio of each component for profile 110 in the list:  [0.82780653 0.14546496]
# explained variance ratio of each component for profile 111 in the list:  [0.8265602  0.14934736]
# explained variance ratio of each component for profile 112 in the list:  [0.82636876 0.14744149]
# explained variance ratio of each component for profile 113 in the list:  [0.83239661 0.14593198]
# explained variance ratio of each component for profile 114 in the list:  [0.83369787 0.14120112]
# explained variance ratio of each component for profile 115 in the list:  [0.85373104 0.12479105]
# explained variance ratio of each component for profile 116 in the list:  [0.86548459 0.11623605]
# explained variance ratio of each component for profile 117 in the list:  [0.86539537 0.11464886]
# explained variance ratio of each component for profile 118 in the list:  [0.86566068 0.11298757]
# explained variance ratio of each component for profile 119 in the list:  [0.87894745 0.10194881]
# explained variance ratio of each component for profile 120 in the list:  [0.87848234 0.10261294]
# explained variance ratio of each component for profile 121 in the list:  [0.89400221 0.08816788]
# explained variance ratio of each component for profile 122 in the list:  [0.8791807  0.10172885]
# explained variance ratio of each component for profile 123 in the list:  [0.87739729 0.10300739]
# explained variance ratio of each component for profile 124 in the list:  [0.87820966 0.10012913]
# explained variance ratio of each component for profile 125 in the list:  [0.88483655 0.10532712]
# explained variance ratio of each component for profile 126 in the list:  [0.88215781 0.09824819]
# explained variance ratio of each component for profile 127 in the list:  [0.87959439 0.10014066]
# explained variance ratio of each component for profile 128 in the list:  [0.8775337  0.10181357]
# explained variance ratio of each component for profile 129 in the list:  [0.879182   0.10016949]
# explained variance ratio of each component for profile 130 in the list:  [0.87535069 0.10400159]
# explained variance ratio of each component for profile 131 in the list:  [0.85366687 0.10209953]
# explained variance ratio of each component for profile 132 in the list:  [0.88996043 0.10198649]
# explained variance ratio of each component for profile 133 in the list:  [0.88856021 0.10130953]
# explained variance ratio of each component for profile 134 in the list:  [0.89025005 0.10105572]
# explained variance ratio of each component for profile 135 in the list:  [0.89405643 0.09584525]
# explained variance ratio of each component for profile 136 in the list:  [0.87226553 0.09093318]
# explained variance ratio of each component for profile 137 in the list:  [0.87294044 0.08811965]
# explained variance ratio of each component for profile 138 in the list:  [0.88031098 0.10491311]
# explained variance ratio of each component for profile 139 in the list:  [0.86921552 0.1113403 ]
# explained variance ratio of each component for profile 140 in the list:  [0.87798559 0.11322891]
# explained variance ratio of each component for profile 141 in the list:  [0.87475609 0.11440057]
# explained variance ratio of each component for profile 142 in the list:  [0.85336329 0.12023432]
# explained variance ratio of each component for profile 143 in the list:  [0.84820455 0.12239326]
# explained variance ratio of each component for profile 144 in the list:  [0.84936353 0.12261073]
# explained variance ratio of each component for profile 145 in the list:  [0.8503563  0.11945086]
# explained variance ratio of each component for profile 146 in the list:  [0.85336296 0.12031866]
# explained variance ratio of each component for profile 147 in the list:  [0.84761563 0.12213513]
# explained variance ratio of each component for profile 148 in the list:  [0.86593914 0.1102137 ]
# explained variance ratio of each component for profile 149 in the list:  [0.8718864  0.10190529]
# explained variance ratio of each component for profile 150 in the list:  [0.89105612 0.08714405]
# explained variance ratio of each component for profile 151 in the list:  [0.89100973 0.08843093]
# explained variance ratio of each component for profile 152 in the list:  [0.89009533 0.08963974]
# explained variance ratio of each component for profile 153 in the list:  [0.96539102 0.03007489]
# explained variance ratio of each component for profile 154 in the list:  [0.96697676 0.03079636]
# explained variance ratio of each component for profile 155 in the list:  [0.9602013  0.03686904]
# explained variance ratio of each component for profile 156 in the list:  [0.96843021 0.0287969 ]
# explained variance ratio of each component for profile 157 in the list:  [0.96753373 0.02997665]
# explained variance ratio of each component for profile 158 in the list:  [0.96890958 0.02852828]
# explained variance ratio of each component for profile 159 in the list:  [0.96907722 0.02811358]
# explained variance ratio of each component for profile 160 in the list:  [0.96810434 0.02915578]
# explained variance ratio of each component for profile 161 in the list:  [0.96842808 0.02948286]
# explained variance ratio of each component for profile 162 in the list:  [0.9683918  0.02895665]
# explained variance ratio of each component for profile 163 in the list:  [0.95975672 0.03008718]
# explained variance ratio of each component for profile 164 in the list:  [0.96673388 0.02919436]
# explained variance ratio of each component for profile 165 in the list:  [0.96834857 0.02852213]
# explained variance ratio of each component for profile 166 in the list:  [0.96841179 0.02856074]
# explained variance ratio of each component for profile 167 in the list:  [0.96879495 0.02814453]
# explained variance ratio of each component for profile 168 in the list:  [0.96831814 0.02908965]
# explained variance ratio of each component for profile 169 in the list:  [0.96894032 0.02789854]
# explained variance ratio of each component for profile 170 in the list:  [0.96948523 0.02757348]
# explained variance ratio of each component for profile 171 in the list:  [0.96968793 0.02731794]
# explained variance ratio of each component for profile 172 in the list:  [0.96123703 0.02771548]
# explained variance ratio of each component for profile 173 in the list:  [0.96895403 0.02801556]
# explained variance ratio of each component for profile 174 in the list:  [0.96895816 0.02757271]
# explained variance ratio of each component for profile 175 in the list:  [0.96845962 0.02844305]
# explained variance ratio of each component for profile 176 in the list:  [0.96810368 0.02773487]
# explained variance ratio of each component for profile 177 in the list:  [0.96599055 0.02954421]
# explained variance ratio of each component for profile 178 in the list:  [0.96608139 0.0290586 ]
# explained variance ratio of each component for profile 179 in the list:  [0.96640606 0.02898087]
# explained variance ratio of each component for profile 180 in the list:  [0.96927926 0.02575635]
# explained variance ratio of each component for profile 181 in the list:  [0.97178038 0.02377816]
# explained variance ratio of each component for profile 182 in the list:  [0.97218771 0.02356582]
# explained variance ratio of each component for profile 183 in the list:  [0.90149829 0.08824289]
# explained variance ratio of each component for profile 184 in the list:  [0.88656183 0.08627376]
# explained variance ratio of each component for profile 185 in the list:  [0.88526211 0.08772493]
# explained variance ratio of each component for profile 186 in the list:  [0.87214733 0.08920029]
# explained variance ratio of each component for profile 187 in the list:  [0.89031068 0.09588504]
# explained variance ratio of each component for profile 188 in the list:  [0.87922855 0.09644216]
# explained variance ratio of each component for profile 189 in the list:  [0.87715987 0.09822041]
# explained variance ratio of each component for profile 190 in the list:  [0.8751277  0.09987518]
# explained variance ratio of each component for profile 191 in the list:  [0.87527276 0.10047293]
# explained variance ratio of each component for profile 192 in the list:  [0.87438498 0.10431461]
# explained variance ratio of each component for profile 193 in the list:  [0.87273435 0.10376873]
# explained variance ratio of each component for profile 194 in the list:  [0.88184318 0.10699784]
# explained variance ratio of each component for profile 195 in the list:  [0.87507459 0.10356897]
# explained variance ratio of each component for profile 196 in the list:  [0.87048119 0.10570491]
# explained variance ratio of each component for profile 197 in the list:  [0.86469697 0.10793851]
# explained variance ratio of each component for profile 198 in the list:  [0.86916972 0.10641541]
# explained variance ratio of each component for profile 199 in the list:  [0.86586215 0.10319344]
# explained variance ratio of each component for profile 200 in the list:  [0.86742735 0.10786792]
# explained variance ratio of each component for profile 201 in the list:  [0.85897223 0.11776416]
# explained variance ratio of each component for profile 202 in the list:  [0.84753501 0.11622654]
# explained variance ratio of each component for profile 203 in the list:  [0.84357864 0.11982737]
# explained variance ratio of each component for profile 204 in the list:  [0.84739318 0.1262905 ]
# explained variance ratio of each component for profile 205 in the list:  [0.84430928 0.12540748]
# explained variance ratio of each component for profile 206 in the list:  [0.83220532 0.12571853]
# explained variance ratio of each component for profile 207 in the list:  [0.83851077 0.13142061]
# explained variance ratio of each component for profile 208 in the list:  [0.84918441 0.12528186]
# explained variance ratio of each component for profile 209 in the list:  [0.84746098 0.12482899]
# explained variance ratio of each component for profile 210 in the list:  [0.84910997 0.12495786]
# explained variance ratio of each component for profile 211 in the list:  [0.87864952 0.10181882]
# explained variance ratio of each component for profile 212 in the list:  [0.88106847 0.10307405]
# explained variance ratio of each component for profile 213 in the list:  [0.88440294 0.1052556 ]
# explained variance ratio of each component for profile 214 in the list:  [0.87958663 0.10113951]
# explained variance ratio of each component for profile 215 in the list:  [0.88745837 0.06793427]
# explained variance ratio of each component for profile 216 in the list:  [0.88760773 0.06829206]
# explained variance ratio of each component for profile 217 in the list:  [0.8846902  0.07144124]
# explained variance ratio of each component for profile 218 in the list:  [0.89031584 0.08599242]
# explained variance ratio of each component for profile 219 in the list:  [0.88168009 0.09864937]
# explained variance ratio of each component for profile 220 in the list:  [0.87274565 0.107106  ]
# explained variance ratio of each component for profile 221 in the list:  [0.86506991 0.11493356]
# explained variance ratio of each component for profile 222 in the list:  [0.84784332 0.12845747]
# explained variance ratio of each component for profile 223 in the list:  [0.85072377 0.12734242]
# explained variance ratio of each component for profile 224 in the list:  [0.84578022 0.13162043]
# explained variance ratio of each component for profile 225 in the list:  [0.8484633  0.13652735]
# explained variance ratio of each component for profile 226 in the list:  [0.83969791 0.13595309]
# explained variance ratio of each component for profile 227 in the list:  [0.83669905 0.1385007 ]
# explained variance ratio of each component for profile 228 in the list:  [0.83261669 0.13631415]
# explained variance ratio of each component for profile 229 in the list:  [0.84130926 0.13382009]
# explained variance ratio of each component for profile 230 in the list:  [0.84346321 0.13305585]
# explained variance ratio of each component for profile 231 in the list:  [0.84019804 0.13742003]
# explained variance ratio of each component for profile 232 in the list:  [0.83185986 0.13130769]
# explained variance ratio of each component for profile 233 in the list:  [0.82559415 0.13449488]
# explained variance ratio of each component for profile 234 in the list:  [0.82631292 0.13537322]
# explained variance ratio of each component for profile 235 in the list:  [0.83074434 0.14346083]
# explained variance ratio of each component for profile 236 in the list:  [0.84612236 0.14115272]
# explained variance ratio of each component for profile 237 in the list:  [0.83665401 0.13882291]
# explained variance ratio of each component for profile 238 in the list:  [0.83441043 0.14134843]
# explained variance ratio of each component for profile 239 in the list:  [0.83263592 0.14552062]
# explained variance ratio of each component for profile 240 in the list:  [0.83818138 0.14660502]
# explained variance ratio of each component for profile 241 in the list:  [0.84821765 0.13564403]
# explained variance ratio of each component for profile 242 in the list:  [0.85817217 0.13064601]
# explained variance ratio of each component for profile 243 in the list:  [0.85462115 0.12873113]
# explained variance ratio of each component for profile 244 in the list:  [0.86017166 0.13005975]
# explained variance ratio of each component for profile 245 in the list:  [0.84981922 0.12586194]
# explained variance ratio of each component for profile 246 in the list:  [0.85395393 0.13245028]
# explained variance ratio of each component for profile 247 in the list:  [0.84631431 0.1242252 ]
# explained variance ratio of each component for profile 248 in the list:  [0.84461703 0.12473766]
# explained variance ratio of each component for profile 249 in the list:  [0.84440284 0.13355166]
# explained variance ratio of each component for profile 250 in the list:  [0.85635625 0.12272453]
# explained variance ratio of each component for profile 251 in the list:  [0.857683   0.12716976]
# explained variance ratio of each component for profile 252 in the list:  [0.85171509 0.13620091]
# explained variance ratio of each component for profile 253 in the list:  [0.85769435 0.12512568]
# explained variance ratio of each component for profile 254 in the list:  [0.85786643 0.1297188 ]
# explained variance ratio of each component for profile 255 in the list:  [0.86911565 0.114338  ]
# explained variance ratio of each component for profile 256 in the list:  [0.8533743  0.12072732]
# explained variance ratio of each component for profile 257 in the list:  [0.86081349 0.1186568 ]
# explained variance ratio of each component for profile 258 in the list:  [0.85916072 0.12839003]
# explained variance ratio of each component for profile 259 in the list:  [0.83195093 0.14350282]
# explained variance ratio of each component for profile 260 in the list:  [0.84529923 0.14175317]
# explained variance ratio of each component for profile 261 in the list:  [0.83936589 0.1470277 ]
# explained variance ratio of each component for profile 262 in the list:  [0.82816325 0.15064926]
# explained variance ratio of each component for profile 263 in the list:  [0.81793747 0.16485399]
# explained variance ratio of each component for profile 264 in the list:  [0.82498143 0.16037836]
# explained variance ratio of each component for profile 265 in the list:  [0.82057238 0.16292477]
# explained variance ratio of each component for profile 266 in the list:  [0.82550534 0.15981724]
# explained variance ratio of each component for profile 267 in the list:  [0.83448749 0.14693044]
# explained variance ratio of each component for profile 268 in the list:  [0.82556458 0.15585843]
# explained variance ratio of each component for profile 269 in the list:  [0.81002869 0.17480033]
# explained variance ratio of each component for profile 270 in the list:  [0.80393374 0.17427707]
# explained variance ratio of each component for profile 271 in the list:  [0.83164639 0.14383834]
# explained variance ratio of each component for profile 272 in the list:  [0.8652719  0.11171307]
# explained variance ratio of each component for profile 273 in the list:  [0.87125696 0.11453765]
# explained variance ratio of each component for profile 274 in the list:  [0.87071615 0.11615169]
# explained variance ratio of each component for profile 275 in the list:  [0.86765343 0.11769024]
# explained variance ratio of each component for profile 276 in the list:  [0.86594063 0.12296293]
# explained variance ratio of each component for profile 277 in the list:  [0.86001343 0.12834007]
# explained variance ratio of each component for profile 278 in the list:  [0.84595163 0.14282962]
# explained variance ratio of each component for profile 279 in the list:  [0.85728939 0.12644778]
# explained variance ratio of each component for profile 280 in the list:  [0.84481688 0.13615721]
# explained variance ratio of each component for profile 281 in the list:  [0.82727692 0.15449766]
# explained variance ratio of each component for profile 282 in the list:  [0.82861614 0.15644379]
# explained variance ratio of each component for profile 283 in the list:  [0.84174167 0.14385364]
# explained variance ratio of each component for profile 284 in the list:  [0.85063854 0.13335588]
# explained variance ratio of each component for profile 285 in the list:  [0.83787242 0.14729892]
# explained variance ratio of each component for profile 286 in the list:  [0.83385085 0.15241725]
# explained variance ratio of each component for profile 287 in the list:  [0.83626403 0.14898163]
# explained variance ratio of each component for profile 288 in the list:  [0.84308077 0.14488647]
# explained variance ratio of each component for profile 289 in the list:  [0.8378819  0.14454093]
# explained variance ratio of each component for profile 290 in the list:  [0.82663306 0.14325231]
# explained variance ratio of each component for profile 291 in the list:  [0.82314933 0.14607882]
# explained variance ratio of each component for profile 292 in the list:  [0.83113321 0.15271836]
# explained variance ratio of each component for profile 293 in the list:  [0.83155429 0.15639859]
# explained variance ratio of each component for profile 294 in the list:  [0.83676029 0.14666335]
# explained variance ratio of each component for profile 295 in the list:  [0.83323776 0.15445344]
# explained variance ratio of each component for profile 296 in the list:  [0.85078945 0.1382328 ]
# explained variance ratio of each component for profile 297 in the list:  [0.83162151 0.13708447]
# explained variance ratio of each component for profile 298 in the list:  [0.83677426 0.13898609]
# explained variance ratio of each component for profile 299 in the list:  [0.8510219  0.13560677]
# explained variance ratio of each component for profile 300 in the list:  [0.84480773 0.13553693]
# explained variance ratio of each component for profile 301 in the list:  [0.83990528 0.14411065]
# explained variance ratio of each component for profile 302 in the list:  [0.84338059 0.12992149]
# explained variance ratio of each component for profile 303 in the list:  [0.83774424 0.13975459]
# explained variance ratio of each component for profile 304 in the list:  [0.85948619 0.12563264]
# explained variance ratio of each component for profile 305 in the list:  [0.86077013 0.12537336]
# explained variance ratio of each component for profile 306 in the list:  [0.85539982 0.13108301]
# explained variance ratio of each component for profile 307 in the list:  [0.85158298 0.1357395 ]
# explained variance ratio of each component for profile 308 in the list:  [0.85370101 0.13376326]
# explained variance ratio of each component for profile 309 in the list:  [0.84302799 0.13907035]
# explained variance ratio of each component for profile 310 in the list:  [0.84716209 0.13761855]
# explained variance ratio of each component for profile 311 in the list:  [0.84113626 0.14441998]
# explained variance ratio of each component for profile 312 in the list:  [0.82007515 0.15968843]
# explained variance ratio of each component for profile 313 in the list:  [0.82409218 0.15901241]
# explained variance ratio of each component for profile 314 in the list:  [0.82877329 0.1520585 ]
# explained variance ratio of each component for profile 315 in the list:  [0.83858553 0.14590476]
# explained variance ratio of each component for profile 316 in the list:  [0.82885514 0.15700391]
# explained variance ratio of each component for profile 317 in the list:  [0.85612648 0.1311957 ]
# explained variance ratio of each component for profile 318 in the list:  [0.84349497 0.14364691]
# explained variance ratio of each component for profile 319 in the list:  [0.85604604 0.12880131]
# explained variance ratio of each component for profile 320 in the list:  [0.8505925  0.13432367]
# explained variance ratio of each component for profile 321 in the list:  [0.8466117  0.13331623]
# explained variance ratio of each component for profile 322 in the list:  [0.83880326 0.14259631]
# explained variance ratio of each component for profile 323 in the list:  [0.86032249 0.12393456]
# explained variance ratio of each component for profile 324 in the list:  [0.86368246 0.11913275]
# explained variance ratio of each component for profile 325 in the list:  [0.84337463 0.13521027]
# explained variance ratio of each component for profile 326 in the list:  [0.84521011 0.1375195 ]
# explained variance ratio of each component for profile 327 in the list:  [0.85753464 0.12601252]
# explained variance ratio of each component for profile 328 in the list:  [0.86268174 0.12307002]
# explained variance ratio of each component for profile 329 in the list:  [0.85027119 0.12994476]
# explained variance ratio of each component for profile 330 in the list:  [0.85279999 0.12650959]
# explained variance ratio of each component for profile 331 in the list:  [0.8450423  0.13199562]
# explained variance ratio of each component for profile 332 in the list:  [0.90141057 0.07982792]
# explained variance ratio of each component for profile 333 in the list:  [0.90083384 0.07855485]
# explained variance ratio of each component for profile 334 in the list:  [0.90671603 0.07721057]
# explained variance ratio of each component for profile 335 in the list:  [0.89794004 0.0830451 ]
# explained variance ratio of each component for profile 336 in the list:  [0.88742517 0.09281795]
# explained variance ratio of each component for profile 337 in the list:  [0.8749651  0.10035895]
# explained variance ratio of each component for profile 338 in the list:  [0.89100267 0.08761477]
# explained variance ratio of each component for profile 339 in the list:  [0.87249635 0.10594355]
# explained variance ratio of each component for profile 340 in the list:  [0.88491593 0.09733326]
# explained variance ratio of each component for profile 341 in the list:  [0.89597047 0.08758776]
# explained variance ratio of each component for profile 342 in the list:  [0.87397513 0.0937194 ]
# explained variance ratio of each component for profile 343 in the list:  [0.87967407 0.09048793]
# explained variance ratio of each component for profile 344 in the list:  [0.86392366 0.0897947 ]
# explained variance ratio of each component for profile 345 in the list:  [0.8539328  0.08308125]
# explained variance ratio of each component for profile 346 in the list:  [0.90872002 0.07604318]
# explained variance ratio of each component for profile 347 in the list:  [0.90235385 0.08280959]
# explained variance ratio of each component for profile 348 in the list:  [0.90916158 0.07725141]
# explained variance ratio of each component for profile 349 in the list:  [0.89306483 0.09382469]
# explained variance ratio of each component for profile 350 in the list:  [0.87090061 0.10489584]
# explained variance ratio of each component for profile 351 in the list:  [0.8693511  0.10558011]
# explained variance ratio of each component for profile 352 in the list:  [0.88585464 0.09668322]
# explained variance ratio of each component for profile 353 in the list:  [0.88126556 0.10203715]
# explained variance ratio of each component for profile 354 in the list:  [0.88005414 0.10128763]
# explained variance ratio of each component for profile 355 in the list:  [0.88375603 0.09604964]
# explained variance ratio of each component for profile 356 in the list:  [0.86857648 0.11018861]
# explained variance ratio of each component for profile 357 in the list:  [0.85217791 0.12452058]
# explained variance ratio of each component for profile 358 in the list:  [0.88479546 0.09677909]
# explained variance ratio of each component for profile 359 in the list:  [0.84701996 0.14001169]
# explained variance ratio of each component for profile 360 in the list:  [0.85287738 0.13412221]
# explained variance ratio of each component for profile 361 in the list:  [0.87700699 0.10454472]
# explained variance ratio of each component for profile 362 in the list:  [0.8804978  0.10093458]
# explained variance ratio of each component for profile 363 in the list:  [0.88443889 0.10652945]
# explained variance ratio of each component for profile 364 in the list:  [0.88279627 0.10643284]
# explained variance ratio of each component for profile 365 in the list:  [0.89948739 0.0915826 ]
# explained variance ratio of each component for profile 366 in the list:  [0.89190282 0.09843504]
# explained variance ratio of each component for profile 367 in the list:  [0.89515301 0.09640056]
# explained variance ratio of each component for profile 368 in the list:  [0.88260746 0.10395234]
# explained variance ratio of each component for profile 369 in the list:  [0.88116077 0.1013627 ]
# explained variance ratio of each component for profile 370 in the list:  [0.8788914  0.10596466]
# explained variance ratio of each component for profile 371 in the list:  [0.87418407 0.1132725 ]
# explained variance ratio of each component for profile 372 in the list:  [0.87236924 0.1162569 ]
# explained variance ratio of each component for profile 373 in the list:  [0.54459952 0.1584246 ]
# explained variance ratio of each component for profile 374 in the list:  [0.84196562 0.11556755]
# explained variance ratio of each component for profile 375 in the list:  [0.85243289 0.11090898]
# explained variance ratio of each component for profile 376 in the list:  [0.86276938 0.12375134]
# explained variance ratio of each component for profile 377 in the list:  [0.86047326 0.12843956]
# explained variance ratio of each component for profile 378 in the list:  [0.85650404 0.12587151]
# explained variance ratio of each component for profile 379 in the list:  [0.84897776 0.13119354]
# explained variance ratio of each component for profile 380 in the list:  [0.87371804 0.1141654 ]
# explained variance ratio of each component for profile 381 in the list:  [0.84209072 0.1378486 ]
# explained variance ratio of each component for profile 382 in the list:  [0.85831678 0.12649494]
# explained variance ratio of each component for profile 383 in the list:  [0.86941789 0.11744186]
# explained variance ratio of each component for profile 384 in the list:  [0.86031739 0.09427799]
# explained variance ratio of each component for profile 385 in the list:  [0.86233301 0.12317401]
# explained variance ratio of each component for profile 386 in the list:  [0.86244301 0.12419541]
# explained variance ratio of each component for profile 387 in the list:  [0.85650249 0.12995649]
# explained variance ratio of each component for profile 388 in the list:  [0.85989985 0.12558303]
# explained variance ratio of each component for profile 389 in the list:  [0.85545087 0.12528325]
# explained variance ratio of each component for profile 390 in the list:  [0.85660258 0.13111634]
# explained variance ratio of each component for profile 391 in the list:  [0.84796221 0.14051248]
# explained variance ratio of each component for profile 392 in the list:  [0.87351778 0.11362164]
# explained variance ratio of each component for profile 393 in the list:  [0.85856569 0.12659459]
# explained variance ratio of each component for profile 394 in the list:  [0.89791072 0.09494186]
# explained variance ratio of each component for profile 395 in the list:  [0.85514324 0.12142304]
# explained variance ratio of each component for profile 396 in the list:  [0.89136607 0.09816988]
# explained variance ratio of each component for profile 397 in the list:  [0.89106712 0.09955083]
# explained variance ratio of each component for profile 398 in the list:  [0.87946509 0.10947675]
# explained variance ratio of each component for profile 399 in the list:  [0.88474163 0.10624176]
# explained variance ratio of each component for profile 400 in the list:  [0.88235588 0.10964098]
# explained variance ratio of each component for profile 401 in the list:  [0.86793196 0.11894168]
# explained variance ratio of each component for profile 402 in the list:  [0.86608858 0.11196511]
# explained variance ratio of each component for profile 403 in the list:  [0.85981978 0.12846779]
# explained variance ratio of each component for profile 404 in the list:  [0.86595513 0.12279024]
# explained variance ratio of each component for profile 405 in the list:  [0.84604454 0.13683724]
# explained variance ratio of each component for profile 406 in the list:  [0.82687134 0.14143649]
# explained variance ratio of each component for profile 407 in the list:  [0.84850758 0.13985024]
# explained variance ratio of each component for profile 408 in the list:  [0.83484597 0.14964621]
# explained variance ratio of each component for profile 409 in the list:  [0.84364628 0.13907329]
# explained variance ratio of each component for profile 410 in the list:  [0.84093497 0.14029052]
# explained variance ratio of each component for profile 411 in the list:  [0.83648207 0.14827432]
# explained variance ratio of each component for profile 412 in the list:  [0.83012244 0.14912697]
# explained variance ratio of each component for profile 413 in the list:  [0.84082456 0.12977535]
# explained variance ratio of each component for profile 414 in the list:  [0.85207766 0.13831903]
# explained variance ratio of each component for profile 415 in the list:  [0.85598393 0.13160729]
# explained variance ratio of each component for profile 416 in the list:  [0.85919836 0.12774862]
# explained variance ratio of each component for profile 417 in the list:  [0.85348818 0.13331825]
# explained variance ratio of each component for profile 418 in the list:  [0.84639873 0.13564054]
# explained variance ratio of each component for profile 419 in the list:  [0.84023202 0.14103263]
# explained variance ratio of each component for profile 420 in the list:  [0.85789054 0.13006999]
# explained variance ratio of each component for profile 421 in the list:  [0.84428608 0.13708852]
# explained variance ratio of each component for profile 422 in the list:  [0.86358234 0.11041986]
# explained variance ratio of each component for profile 423 in the list:  [0.84521286 0.13697945]
# explained variance ratio of each component for profile 424 in the list:  [0.86933823 0.12153449]
# explained variance ratio of each component for profile 425 in the list:  [0.86825228 0.12195571]
# explained variance ratio of each component for profile 426 in the list:  [0.85458335 0.13028035]
# explained variance ratio of each component for profile 427 in the list:  [0.86969108 0.12039232]
# explained variance ratio of each component for profile 428 in the list:  [0.86411959 0.12465072]
# explained variance ratio of each component for profile 429 in the list:  [0.86736684 0.12172426]
# explained variance ratio of each component for profile 430 in the list:  [0.87010787 0.11503618]
# explained variance ratio of each component for profile 431 in the list:  [0.87023506 0.11985885]
# explained variance ratio of each component for profile 432 in the list:  [0.86316931 0.12079626]
# explained variance ratio of each component for profile 433 in the list:  [0.85932915 0.12723562]
# explained variance ratio of each component for profile 434 in the list:  [0.8556612  0.12858176]
# explained variance ratio of each component for profile 435 in the list:  [0.8335139  0.14773069]
# explained variance ratio of each component for profile 436 in the list:  [0.8443113  0.13790287]
# explained variance ratio of each component for profile 437 in the list:  [0.86050467 0.12738082]
# explained variance ratio of each component for profile 438 in the list:  [0.85555519 0.12798579]
# explained variance ratio of each component for profile 439 in the list:  [0.83455277 0.14084385]
# explained variance ratio of each component for profile 440 in the list:  [0.83991108 0.13454086]
# explained variance ratio of each component for profile 441 in the list:  [0.85126551 0.13227724]
# explained variance ratio of each component for profile 442 in the list:  [0.83788178 0.14136031]
# explained variance ratio of each component for profile 443 in the list:  [0.86288979 0.1201618 ]
# explained variance ratio of each component for profile 444 in the list:  [0.85531509 0.12453411]
# explained variance ratio of each component for profile 445 in the list:  [0.85420269 0.12410106]
# explained variance ratio of each component for profile 446 in the list:  [0.86597052 0.08055002]
# explained variance ratio of each component for profile 447 in the list:  [0.83404284 0.1290658 ]
# explained variance ratio of each component for profile 448 in the list:  [0.82824866 0.14790822]
# explained variance ratio of each component for profile 449 in the list:  [0.85002408 0.12842518]
# explained variance ratio of each component for profile 450 in the list:  [0.82335494 0.15074393]
# explained variance ratio of each component for profile 451 in the list:  [0.81380378 0.16037182]
# explained variance ratio of each component for profile 452 in the list:  [0.85924252 0.12542827]
# explained variance ratio of each component for profile 453 in the list:  [0.85826258 0.12338388]
# explained variance ratio of each component for profile 454 in the list:  [0.80100357 0.16721098]
# explained variance ratio of each component for profile 455 in the list:  [0.80465114 0.18268742]
# explained variance ratio of each component for profile 456 in the list:  [0.80958236 0.17895057]
# explained variance ratio of each component for profile 457 in the list:  [0.80573308 0.17227933]
# explained variance ratio of each component for profile 458 in the list:  [0.8163953  0.17265541]
# explained variance ratio of each component for profile 459 in the list:  [0.8140093  0.17375865]
# explained variance ratio of each component for profile 460 in the list:  [0.80050588 0.17460575]
# explained variance ratio of each component for profile 461 in the list:  [0.80437261 0.17090944]
# explained variance ratio of each component for profile 462 in the list:  [0.80121314 0.17688536]
# explained variance ratio of each component for profile 463 in the list:  [0.77688828 0.19919072]
# explained variance ratio of each component for profile 464 in the list:  [0.76457375 0.19997966]
# explained variance ratio of each component for profile 465 in the list:  [0.77034379 0.19901569]
# explained variance ratio of each component for profile 466 in the list:  [0.78756606 0.19122096]
# explained variance ratio of each component for profile 467 in the list:  [0.7578042  0.21065888]
# explained variance ratio of each component for profile 468 in the list:  [0.77773122 0.19416819]
# explained variance ratio of each component for profile 469 in the list:  [0.77559196 0.19637141]
# explained variance ratio of each component for profile 470 in the list:  [0.79122198 0.18319571]
# explained variance ratio of each component for profile 471 in the list:  [0.79575217 0.18249381]
# explained variance ratio of each component for profile 472 in the list:  [0.79188273 0.18529896]
# explained variance ratio of each component for profile 473 in the list:  [0.80306895 0.18507077]
# explained variance ratio of each component for profile 474 in the list:  [0.78565403 0.18810835]
# explained variance ratio of each component for profile 475 in the list:  [0.77269391 0.20162667]
# explained variance ratio of each component for profile 476 in the list:  [0.77542701 0.18894721]
# explained variance ratio of each component for profile 477 in the list:  [0.80338083 0.17505521]
# explained variance ratio of each component for profile 478 in the list:  [0.80092905 0.17594943]
# explained variance ratio of each component for profile 479 in the list:  [0.81322023 0.17190438]
# explained variance ratio of each component for profile 480 in the list:  [0.81297612 0.17276266]
# explained variance ratio of each component for profile 481 in the list:  [0.80548323 0.17183789]
# explained variance ratio of each component for profile 482 in the list:  [0.80530719 0.1693565 ]
# explained variance ratio of each component for profile 483 in the list:  [0.81590716 0.16258882]
# explained variance ratio of each component for profile 484 in the list:  [0.81111762 0.16672767]
# explained variance ratio of each component for profile 485 in the list:  [0.79808993 0.17760222]
# explained variance ratio of each component for profile 486 in the list:  [0.8110136 0.169267 ]
# explained variance ratio of each component for profile 487 in the list:  [0.8105364  0.16973643]
# explained variance ratio of each component for profile 488 in the list:  [0.79915554 0.17699398]
# explained variance ratio of each component for profile 489 in the list:  [0.79661822 0.17913563]
# explained variance ratio of each component for profile 490 in the list:  [0.76894655 0.18202385]
# explained variance ratio of each component for profile 491 in the list:  [0.40798167 0.21363779]
# explained variance ratio of each component for profile 492 in the list:  [0.33912763 0.13388334]
# explained variance ratio of each component for profile 493 in the list:  [0.59181702 0.09657828]
# explained variance ratio of each component for profile 494 in the list:  [0.47883763 0.35247735]

# %%
def reconstruct_dim(X_r_list, pca_list):
    sample_list_rec = []
    for m in range(len(X_r_list)):
        nComp = pca_list[m].n_components
        sample_list_rec.append(np.dot(X_r_list[m], pca_list[m].components_[:nComp,:]))
    return sample_list_rec

# %%
sample_list_rec = reconstruct_dim(X_r_list, pca_list)

# %%
def reconstruct_data(dft_list, pc, dates, sample_list_rec):
    for m in range(len(dates)):
        print('reconstruct data formation progress: {:.3f}%   '.format(100*m/len(dates)), end='\r')
        for c in range(len(pc)):
            instance = dft_list[c].loc[dft_list[c]['settlement_date'].dt.date==dates[m], 'avg_vol_per_mpan']
            if (len(instance) == 48) and (instance is True):
                dft_list[c].loc[dft_list[c]['settlement_date'].dt.date==dates[m], 'avg_vol_per_mpan'] = sample_list_rec[m][c,:]
            else:
                pass  
    print('reconstruct matrix formation progress: 100.000%', end='\r')
    return dft_list

# %%
dft_list_rec = reconstruct_data(dft_list, pc, dates, sample_list_rec)
# Out:
# reconstruct matrix formation progress: 100.000%

# %%
dft_rec = pd.DataFrame(np.vstack(dft_list_rec))
dft_rec.columns = dft.columns

# %%
with open('reconstructable data.pickle', 'wb') as f:
            pickle.dump(sample_list, f)
        
with open('reconstructed data.pickle', 'wb') as f:
            pickle.dump(dft_rec, f)
